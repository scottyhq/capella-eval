# %% [markdown]
# # Keep track of tasking deliveries
#
# Time between task and acquisition
#
# Time between acquisition and delivery

# %%
import capella_console_client
import geopandas as gpd
import pandas as pd
import json

# %%
with open('/home/jovyan/capella/credentials.json') as f: # USER: Input path to credentials.json file.
    data = json.load(f)
    username = data['username']
    password = data['password']

client =  capella_console_client.CapellaConsoleClient(username, password)

# %%
gf = gpd.GeoDataFrame.from_features(client.list_tasking_requests())
len(gf)
# Out:
# 39

# %%
# Remove cancelled orders
gf['final_status'] = gf['statusHistory'].apply(lambda x: x[0]['code']) #final_status
gf = gf[gf.final_status == 'completed']
len(gf)
# Out:
# 14

# %%
# Consider only 1_day tier
gf = gf[gf.collectionTier == '1_day']
len(gf)
# Out:
# 13

# %%
task_history = pd.DataFrame(gf.iloc[0].statusHistory)
task_history
# Out:
#                          time       code  \
# 0  2023-10-06T12:31:33.696000  completed
# 1  2023-10-06T01:32:17.797000   accepted
# 2  2023-10-06T01:29:10.611000  submitted
# 3  2023-10-06T00:45:03.709000     review
# 4  2023-10-06T00:45:01.576000   received
#
#                                              message
# 0                Tasking request has been completed.
# 1  Request can be completely satisfied during val...
# 2      Request approved and submitted for scheduling
# 3                  Tasking request ready for review.
# 4                                    Request created

# %%
def time2delivery(row):
    df = pd.DataFrame(row.statusHistory)
    df['time'] = pd.to_datetime(df.time)
    dt = df[df.code == 'completed'].iloc[0].time - df[df.code == 'submitted'].iloc[0].time
    dt = dt / pd.Timedelta(hours=1)
    return dt

# %%
time2delivery(gf.iloc[0])
# Out:
# 11.039745833333333

# %%
print('Submission to delivery (hrs)')
gf.apply(time2delivery, axis=1).describe().apply('{:,.1f}'.format)
# Out:
# Submission to delivery (hrs)
# count    13.0
# mean     24.0
# std      19.9
# min       4.7
# 25%      11.0
# 50%      18.3
# 75%      26.8
# max      73.8
# dtype: object

# %%
#? which task took 73 hours?
gf['time2deliver'] = gf.apply(time2delivery, axis=1)
cols = ['time2deliver','taskingrequestName','taskingrequestDescription']
gf[cols]
# Out:
#     time2deliver                  taskingrequestName  \
# 0      11.039746                Paradise: subdaily-9
# 2      11.395361               Paradise: subdaily-10
# 7      26.779765                Paradise: subdaily-6
# 10     18.334758      Paradise Snotel 45 Retask Oct2
# 11     73.809439                 Baker Field Work: 3
# 12     43.701188                 Baker Field Work: 2
# 13     10.944945                 Baker Field Work: 1
# 14     47.211687          Rainier 53 NE Strip Retask
# 15     12.848820           Paradise Snotel 45 Retask
# 18     23.174859                 Rainier 53 NE Strip
# 33      7.137082                  Jakobshavn Test: 1
# 34      4.660734  Mt Rainier Gibraltar Rock 2 Retask
# 37     20.993566           Mt Rainier Gibraltar Rock
#
#                             taskingrequestDescription
# 0                              Paradise subdaily test
# 2                              Paradise subdaily test
# 7                              Paradise subdaily test
# 10  snotel station spotlight (ID: b3cc101b-ebe0-4d...
# 11                                     Easton glacier
# 12                                     Easton glacier
# 13                                     Easton glacier
# 14  camp muir, NE strike (ID: 033fd86f-9271-42d9-9...
# 15  snotel station spotlight (ID: b3cc101b-ebe0-4d...
# 18                               camp muir, NE strike
# 33                              Jackobshavn attempt 1
# 34  Mt Rainier Gibraltar, orbit=97, pol=VV, desc (...
# 37             Mt Rainier Gibraltar, orbit=97, pol=VV

# %%
# Doesn't quite work for repeat tasks like Baker field work.

# %%
#gf.windowDuration should be 86400 for 1_day

# %%
gf.iloc[0]
# Out:
# geometry                                  POINT Z (-121.744564 46.796787 1589)
# submissionTime                                      2023-10-06T00:45:01.575000
# taskingrequestId                          89c04f42-e6df-4873-82d3-9c37cf5dc480
# taskingrequestName                                        Paradise: subdaily-9
# taskingrequestDescription                               Paradise subdaily test
# taskingrequestType                                                      custom
# orgId                                     e075d057-19cf-4bfb-9b07-9fee713bb05e
# userId                                    0653314d-010a-423b-8a8e-11ab48983152
# repeatrequestId                                                           None
# windowOpen                                                 2023-10-05T21:18:02
# windowDuration                                                         86401.0
# windowClose                                                2023-10-06T21:18:03
# collectionTier                                                           1_day
# archiveHoldback                                                           none
# statusHistory                [{'time': '2023-10-06T12:31:33.696000', 'code'...
# collectConstraints           {'lookDirection': 'left', 'ascDsc': 'ascending...
# billingEnvironment                                                     default
# parentTaskingrequest                                                      None
# customAttribute1                          e7794ebf-48a0-44dd-891d-7150d58bc44b
# customAttribute2                                                          None
# final_status                                                         completed
# time2deliver                                                         11.039746
# Name: 0, dtype: object

# %%
# Filter for windowOpen within 24 hours of task submission
def submission2open(row):
    dt = pd.to_datetime(row.windowOpen) - pd.to_datetime(row.submissionTime) 
    dt = dt / pd.Timedelta(hours=1)
    return dt

gf['submission2windowOpen'] = gf.apply(submission2open, axis=1)
cols = ['submission2windowOpen','time2deliver','taskingrequestName','taskingrequestDescription']
gf[cols]
# Out:
#     submission2windowOpen  time2deliver                  taskingrequestName  \
# 0               -3.449882     11.039746                Paradise: subdaily-9
# 2               -3.310301     11.395361               Paradise: subdaily-10
# 7               10.587220     26.779765                Paradise: subdaily-6
# 10              -0.022800     18.334758      Paradise Snotel 45 Retask Oct2
# 11              47.626122     73.809439                 Baker Field Work: 3
# 12              23.627516     43.701188                 Baker Field Work: 2
# 13              -0.047348     10.944945                 Baker Field Work: 1
# 14               1.323689     47.211687          Rainier 53 NE Strip Retask
# 15              -0.039153     12.848820           Paradise Snotel 45 Retask
# 18              -0.037969     23.174859                 Rainier 53 NE Strip
# 33              -0.056525      7.137082                  Jakobshavn Test: 1
# 34              -0.054257      4.660734  Mt Rainier Gibraltar Rock 2 Retask
# 37              -0.005940     20.993566           Mt Rainier Gibraltar Rock
#
#                             taskingrequestDescription
# 0                              Paradise subdaily test
# 2                              Paradise subdaily test
# 7                              Paradise subdaily test
# 10  snotel station spotlight (ID: b3cc101b-ebe0-4d...
# 11                                     Easton glacier
# 12                                     Easton glacier
# 13                                     Easton glacier
# 14  camp muir, NE strike (ID: 033fd86f-9271-42d9-9...
# 15  snotel station spotlight (ID: b3cc101b-ebe0-4d...
# 18                               camp muir, NE strike
# 33                              Jackobshavn attempt 1
# 34  Mt Rainier Gibraltar, orbit=97, pol=VV, desc (...
# 37             Mt Rainier Gibraltar, orbit=97, pol=VV

# %%
def acquisition2delivery(row):
    ''' time between satellite collection and imagery delivery '''
    # Slower b/c must go into collects
    collects = client.get_collects_for_task(row.taskingrequestId)
    c = collects[0] #always only 1?
    df = pd.DataFrame(c['collectStatusHistory'])
    
    df['time'] = pd.to_datetime(df.time)
    dt = df[df.code == 'delivered'].iloc[0].time - df[df.code == 'collected'].iloc[0].time
    dt = dt / pd.Timedelta(hours=1)
    return dt

# %%
acquisition2delivery(gf.iloc[0])
# Out:
# 1.4127166666666666

# %%
gf['acquisition2delivery'] = gf.apply(acquisition2delivery, axis=1)

# %%
cols = ['acquisition2delivery','submission2windowOpen','time2deliver','taskingrequestName','taskingrequestDescription']
gf[cols]
# Out:
#     acquisition2delivery  submission2windowOpen  time2deliver  \
# 0               1.412717              -3.449882     11.039746
# 2               2.084954              -3.310301     11.395361
# 7               3.436076              10.587220     26.779765
# 10              1.303516              -0.022800     18.334758
# 11              8.238487              47.626122     73.809439
# 12              2.565781              23.627516     43.701188
# 13              2.780717              -0.047348     10.944945
# 14             20.261465               1.323689     47.211687
# 15              2.316606              -0.039153     12.848820
# 18              2.042424              -0.037969     23.174859
# 33              0.635672              -0.056525      7.137082
# 34            184.720017              -0.054257      4.660734
# 37             12.769648              -0.005940     20.993566
#
#                     taskingrequestName  \
# 0                 Paradise: subdaily-9
# 2                Paradise: subdaily-10
# 7                 Paradise: subdaily-6
# 10      Paradise Snotel 45 Retask Oct2
# 11                 Baker Field Work: 3
# 12                 Baker Field Work: 2
# 13                 Baker Field Work: 1
# 14          Rainier 53 NE Strip Retask
# 15           Paradise Snotel 45 Retask
# 18                 Rainier 53 NE Strip
# 33                  Jakobshavn Test: 1
# 34  Mt Rainier Gibraltar Rock 2 Retask
# 37           Mt Rainier Gibraltar Rock
#
#                             taskingrequestDescription
# 0                              Paradise subdaily test
# 2                              Paradise subdaily test
# 7                              Paradise subdaily test
# 10  snotel station spotlight (ID: b3cc101b-ebe0-4d...
# 11                                     Easton glacier
# 12                                     Easton glacier
# 13                                     Easton glacier
# 14  camp muir, NE strike (ID: 033fd86f-9271-42d9-9...
# 15  snotel station spotlight (ID: b3cc101b-ebe0-4d...
# 18                               camp muir, NE strike
# 33                              Jackobshavn attempt 1
# 34  Mt Rainier Gibraltar, orbit=97, pol=VV, desc (...
# 37             Mt Rainier Gibraltar, orbit=97, pol=VV

# %%
# NOTE: polar orbits probably have longer delivery time due to downlink station distribution

# %%
# What is going on with the re-task?
gf.loc[34]
# Out:
# geometry                                           POINT Z (-121.733 46.842 0)
# submissionTime                                      2023-08-14T16:57:54.083000
# taskingrequestId                          dad725b7-d775-4cc2-b05e-7a94ac238140
# taskingrequestName                          Mt Rainier Gibraltar Rock 2 Retask
# taskingrequestDescription    Mt Rainier Gibraltar, orbit=97, pol=VV, desc (...
# taskingrequestType                                                      custom
# orgId                                     e075d057-19cf-4bfb-9b07-9fee713bb05e
# userId                                    0653314d-010a-423b-8a8e-11ab48983152
# repeatrequestId                                                           None
# windowOpen                                          2023-08-14T16:54:38.757000
# windowDuration                                                       90321.243
# windowClose                                                2023-08-15T18:00:00
# collectionTier                                                           1_day
# archiveHoldback                                                           none
# statusHistory                [{'time': '2023-08-14T21:39:19.317000', 'code'...
# collectConstraints           {'lookDirection': 'either', 'ascDsc': 'either'...
# billingEnvironment                                                     default
# parentTaskingrequest                                                      None
# customAttribute1                                                          None
# customAttribute2                                                          None
# final_status                                                         completed
# time2deliver                                                          4.660734
# submission2windowOpen                                                -0.054257
# acquisition2delivery                                                184.720017
# Name: 34, dtype: object

# %%
gf.loc[34].statusHistory
# Out:
# [{'time': '2023-08-14T21:39:19.317000',
#   'code': 'completed',
#   'message': 'Tasking request has been completed.'},
#  {'time': '2023-08-14T17:01:30.611000',
#   'code': 'accepted',
#   'message': 'Request can be completely satisfied during validity window.'},
#  {'time': '2023-08-14T16:59:40.673000',
#   'code': 'submitted',
#   'message': 'Request approved and submitted for scheduling'},
#  {'time': '2023-08-14T16:58:10.362000',
#   'code': 'review',
#   'message': 'Tasking request ready for review.'},
#  {'time': '2023-08-14T16:57:54.083000',
#   'code': 'received',
#   'message': 'Request created'}]

# %%
def get_collect_history(row):
    collects = client.get_collects_for_task(row.taskingrequestId)
    c = collects[0] #always only 1?
    df = pd.DataFrame(c['collectStatusHistory'])
    return df

test = get_collect_history(gf.loc[34])
test
# Out:
#                         time                code  \
# 0   2023-08-22T12:52:39.720Z           delivered
# 1   2023-08-16T03:55:44.087Z  collection_anomaly
# 2   2023-08-16T03:55:36.266Z           delivered
# 3   2023-08-16T01:16:08.512Z  collection_anomaly
# 4   2023-08-15T15:56:15.143Z           delivered
# 5   2023-08-15T15:56:10.939Z                  qa
# 6   2023-08-15T15:55:50.646Z           delivered
# 7   2023-08-15T15:55:46.144Z                  qa
# 8   2023-08-15T14:38:33.029Z  collection_anomaly
# 9   2023-08-14T21:39:14.009Z           delivered
# 10  2023-08-14T20:56:17.446Z                  qa
# 11  2023-08-14T20:34:19.305Z          processing
# 12  2023-08-14T20:09:27.660Z           collected
# 13  2023-08-14T17:35:40.247Z              tasked
# 14  2023-08-14T16:58:00.126Z           predicted
#
#                                               message
# 0      The products have been processed and delivered
# 1   A collection anomaly has occurred, if possible...
# 2      The products have been processed and delivered
# 3   A collection anomaly has occurred, if possible...
# 4      The products have been processed and delivered
# 5                Products awaiting QA before delivery
# 6      The products have been processed and delivered
# 7                Products awaiting QA before delivery
# 8   A collection anomaly has occurred, if possible...
# 9      The products have been processed and delivered
# 10               Products awaiting QA before delivery
# 11  Processing data from raw to higher level products
# 12     Known to have been collected on the spacecraft
# 13  Collection of image has been incorporated into...
# 14                                    Collect created

# %%
'collection_anomaly' in test.code.values
# Out:
# True

# %%
def check_collection_anomaly(row):
    df = get_collect_history(row)
    check = 'collection_anomaly' in df.code.values
    return check

# %%
check_collection_anomaly(gf.loc[34])
# Out:
# True

# %%
gf['collection_anomaly'] = gf.apply(check_collection_anomaly, axis=1)

# %%
cols = ['collection_anomaly','acquisition2delivery','submission2windowOpen','time2deliver', 'windowDuration','taskingrequestName','taskingrequestDescription']
gf[cols]
# Out:
#     collection_anomaly  acquisition2delivery  submission2windowOpen  \
# 0                False              1.412717              -3.449882
# 2                False              2.084954              -3.310301
# 7                False              3.436076              10.587220
# 10               False              1.303516              -0.022800
# 11               False              8.238487              47.626122
# 12               False              2.565781              23.627516
# 13                True              2.780717              -0.047348
# 14               False             20.261465               1.323689
# 15               False              2.316606              -0.039153
# 18               False              2.042424              -0.037969
# 33               False              0.635672              -0.056525
# 34                True            184.720017              -0.054257
# 37               False             12.769648              -0.005940
#
#     time2deliver  windowDuration                  taskingrequestName  \
# 0      11.039746       86401.000                Paradise: subdaily-9
# 2      11.395361       86401.000               Paradise: subdaily-10
# 7      26.779765       86401.000                Paradise: subdaily-6
# 10     18.334758       86400.000      Paradise Snotel 45 Retask Oct2
# 11     73.809439       86400.000                 Baker Field Work: 3
# 12     43.701188       86400.000                 Baker Field Work: 2
# 13     10.944945       86400.000                 Baker Field Work: 1
# 14     47.211687       86400.000          Rainier 53 NE Strip Retask
# 15     12.848820       86400.000           Paradise Snotel 45 Retask
# 18     23.174859       86400.000                 Rainier 53 NE Strip
# 33      7.137082       86400.000                  Jakobshavn Test: 1
# 34      4.660734       90321.243  Mt Rainier Gibraltar Rock 2 Retask
# 37     20.993566     1209600.000           Mt Rainier Gibraltar Rock
#
#                             taskingrequestDescription
# 0                              Paradise subdaily test
# 2                              Paradise subdaily test
# 7                              Paradise subdaily test
# 10  snotel station spotlight (ID: b3cc101b-ebe0-4d...
# 11                                     Easton glacier
# 12                                     Easton glacier
# 13                                     Easton glacier
# 14  camp muir, NE strike (ID: 033fd86f-9271-42d9-9...
# 15  snotel station spotlight (ID: b3cc101b-ebe0-4d...
# 18                               camp muir, NE strike
# 33                              Jackobshavn attempt 1
# 34  Mt Rainier Gibraltar, orbit=97, pol=VV, desc (...
# 37             Mt Rainier Gibraltar, orbit=97, pol=VV

# %%
print('Submission to delivery (hrs)')
gf.apply(time2delivery, axis=1).describe().apply('{:,.1f}'.format)
# Out:
# Submission to delivery (hrs)
# count    13.0
# mean     24.0
# std      19.9
# min       4.7
# 25%      11.0
# 50%      18.3
# 75%      26.8
# max      73.8
# dtype: object

# %%
# Drop initial task requests with unnecessarily large windows
print('Acquisition to delivery (hrs)')
gf[gf.windowDuration <= 86401].acquisition2delivery.describe().apply('{:,.1f}'.format)
# Out:
# Acquisition to delivery (hrs)
# count    11.0
# mean      4.3
# std       5.7
# min       0.6
# 25%       1.7
# 50%       2.3
# 75%       3.1
# max      20.3
# Name: acquisition2delivery, dtype: object
